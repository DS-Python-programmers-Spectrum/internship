# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\spectrum\anaconda3\lib\site-packages (2.3.5)

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5])

print(arr1)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np

arr2 = np.array([[1, 2, 3], [4, 5, 6]])



print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np

arr3 = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])

print(arr3)
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]

# %%
print(arr3.ndim)
# Out:
# 3

# %%
import numpy as np

arr4 = np.array([1, 2, 3, 4, 5, 6, 7])

print(arr4[2:3])
# Out:
# [3]

# %%
print(arr4[0:4])
# Out:
# [1 2 3 4]
